# %% [markdown]
# # Primera Jornada de Resolución de Problemas: Sucesiones, aproximaciones y continuidad
#
# **Departamento de Matemáticas y Estadística / Facultad de Ingeniería**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# **Descripción de la jornada**: En esta jornada usted va a encontrar tres problemas. Usted debe trabajar en el primero (modelos de enfriamiento) y al menos en uno de los otros dos. Cada problema debe ser abordado de forma individual utilizando todos los recursos que usted disponga. La idea central es que elabore sus respuestas o construcciones siguiendo los lineamientos dados a continuación:
#
# 1. Escriba con claridad sus propias ideas.
# 2. Argumente usando lenguaje propio de las matemáticas: geométrico o algebraico, según sea el caso, cada una de sus respuestas.
# 3. Respalde donde considere conveniente sus argumentos geométricos y algebraicos con imágenes o applets diseñadas en alguna de las herramientas que hacen parte de la mochila digital.
# 4.	Resuelva los problemas de manera preferiblemente autónoma; describiendo estrategias para “atacar” el problema, poniendo a prueba sus soluciones y en lo posible planteando nuevos e “interesantes” interrogantes asociados al problema formulado.

# %% [markdown]
# # Modelando la realidad: modelos de enfriamiento
#
# Suponga que $𝑇_𝑛$ es la temperatura de un café después de $𝑛$ minutos. Sea $𝑆$  la temperatura ambiente de una habitación donde se encuentra el café. Finalmente, suponga entonces  que la diferencia de temperatura en el instante $n+1$ y el instante $n$, es directamente proporcional a la diferencia entre la temperatura  inicial $T_0$ y la temperatura del ambiente $S$. Asuma que la constante de proporcionalidad es $k$, y que ésta se calcula utilizando al menos dos de los valores de las temperaturas durante el proceso de enfriamiento.(*Nota: Lo anterior aplica para cualquier cuerpo en general*)
#
# 1. Escriba una ecuación que de cuenta de la relación anterior  en terminos de una sucesión de valores de la temperatura, es decir, en terminos de $\{T_n\}$, la sucesión de valores de temperatura transcurridos $n$ unidades de tiempo.
#
# $$T_{n+1}-T_n= k (T_0-S)$$
#
# 2. Suponga ahora que le traen a su mesa una taza de café, inicialmente a una temperatura de 80º C, en una habitación que se encuentra a una temperatura ambiente de 20º C. Además, suponga que después de un
# minuto el café se ha enfriado y está en 75º C.
#
#   2.1 Halle la constante de enfriamiento a partir de los datos dados.
#
#   2.2 Encuentre la temperatura del café después de 25 minutos al menos de dos formas distintas: una puede ser numéricamente y la otra intentando deducir una fórmula general para la forma de la solución. (Puede asumir el valor de $k=0.075$ si no supo como encontrarla en el enciso anterior.)
#
#   2.3 Si se le pide encontrar la temperatura de su cafe transcurrido mucho tiempo. ¿Qué formulación matemática podría usted utilizar para inferir dicho valor?¿Puede llegar a esa misma conclusión numéricamente?¿Cómo lo haría?.
#
#   2.4 Grafique los valores de la temperatura y establezca en qué momento, si existe, la temperatura del café se vuelve constante.
#
#   2.5 ¿La temperatura de su café podría llegar alguna vez a 20º C?¿A 10º C? Sustente sus respuestas.

# %% [markdown]
# # Consecuencias de la continuidad: (valores intermedios)
#
# Suponga que una función $f$ es continua sobre un intervalo $[a,b]$.
# 1. Explique por qué si o por qué no, se podría afirmar que para todo $y$ entre $f(a)$ y $f(b)$,  existe un $c\in[a,b]$ tal que $f(c)=y$.
#
# 2. Ilustre la situación anterior con un applet, es decir, utilizando matplotlib o GeoGebra por ejemplo. Puede, por ejemplo, utilizar cualquier función que usted considere continua en un intervalo cerrado adecuado.
#
# 3. Suponga ahora que $f(a) < 0 < f(b)$. De acuerdo con el resultado que estamos formulando, ¿es posible afirmar que la función $f$ tiene un cero real en el intervalo $[a,b]$? Explique su respuesta con dos  de los siguientes tipos de argumentos: algebráico, geométrico o en lenguaje natural.

# %% [markdown]
# # Consecuencias de la continuidad: (optimización)
#
#
# Suponga que una función $f$ es continua sobre un intervalo $[a,b]$.
# 1. Explique por qué si o por qué no, se podría afirmar que siempre existe un valor máximo y un valor mínimo para $f$ en el intervalo $[a,b]$. Es decir, por qué siempre es posible encontrar un valor   $m$ y otro valor $M$ tal que $m \leq f(x) \leq M$ para todo $x\in[a,b]$.
#
# 2. Si usted considera que si es válida la afirmación o proposición anterior, explique si el resultado continuaría siendo cierto cuando el intervalo considerado es abierto, es decir, $(a,b)$. De un par de ejemplos de funciones continuas en un intervalo abierto arbitrario para ilustrar sus conclusiones.
#
# 3. De al menos tres ejemplos de funciones $f,g$ y $h$, de forma  tal que cada una presenta una discontinuidad distinta en el intervalo $I=[-1,1]$. Por ejemplo, $f$ y $g$  tienen una discontinuidad removible y $h$ tiene una asíntota vertical en el intervalo $I$. Utilice una gráfica para apoyar su explicación del por qué en estos casos no es posible garantizar la existencia de un valor máximo o de un valor mínimo o ambos, a diferencia del caso continuo como se describe en el punto 1 de este apartado.

# %%
import numpy as np
import matplotlib.pyplot as plt

N= 50 #
x0 = 80.0 #
k = (-1/12)
xn=[x0]

for n in range(1,N):
  xn.append(60*(1+k)**n + 20)
  #tasa.append(xn[-1]/xn[-2])
  print(xn[n])

plt.plot(xn,'r*')
plt.ylabel("T")
plt.xlabel("t")

#print(1-(1/11))
# Out:
# 75.0
# 70.41666666666666
# 66.21527777777777
# 62.364004629629626
# 58.83367091049382
# 55.597531667952666
# 52.63107069562328
# 49.91181480432134
# 47.41916357062789
# 45.134233273075566
# 43.0397138336526
# 41.11973768084822
# 39.35975954077753
# 37.74644624571273
# 36.267575725236675
# 34.91194441480028
# 33.6692823802336
# 32.530175515214125
# 31.485994222279615
# 30.528828037089646
# 29.65142570066551
# 28.847140225610048
# 28.109878540142546
# 27.434055328463998
# 26.814550717758664
# 26.246671491278775
# 25.726115533672214
# 25.248939239199526
# 24.8115276359329
# 24.41056699960516
# 24.043019749638063
# 23.706101437168222
# 23.39725965073754
# 23.11415467984274
# 22.854641789855847
# 22.616754974034528
# 22.398692059531648
# 22.19880105457068
# 22.015567633356454
# 21.847603663910085
# 21.693636691917575
# 21.552500300924446
# 21.423125275847408
# 21.304531502860122
# 21.19582054428845
# 21.09616883226441
# 21.00482142957571
# 20.921086310444398
# 20.844329117907368
# ...
