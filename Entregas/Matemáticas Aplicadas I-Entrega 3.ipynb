# %% [markdown]
# <img src=https://www.icesi.edu.co/wp-content/uploads/2024/10/ICESI_logo_prin_descriptor_RGB_NEGATIVO_0924-768x395.png  width="300" height="200" align="center">
#
# #**<big><big>Matemáticas Aplicadas II</big></big><br><small>Ciencias Físicas & Exactas / FIDCA</small><br><small>_*Entrega 4*_ (Consecuencias de la continuidad). </small>**
#
# A continuación se le pide contestar o resolver, en **grupos de 4 personas**, las siguientes preguntas utilizando el presente cuaderno para consignar todas sus respuestas.
#
# **Usted debe hacer esta entrega completa el próximo martes 28 de Septiembre antes de la clase.**
#
#
# **<u>Preguntas</u>**
#
# 1. (5 pts) Considere la función $$v(x)=\left\{
# \begin{array}{ll}
#       \frac{x-1}{|x-1|}, & x\not=1 \\
#       1, & x=1.
# \end{array} \right.$$
#
#   1.1 Construya un applet en GeoGebra que dibuje la función $v$ en el intervalo $[-2,2]$.
#
#   1.2 Explique por qué $v$ no es una función continua. ¿Es posible remover la discontinuidad, es decir, se puede redefinir $v$ de forma tal que sea una función continua?
# 2. (24 pts) Considere la función : $$f(x)=\frac{x^{32}+x^{10}+c}{x^2+2}$$ donde $c$ es una constante arbitraria.
#
#   2.1 Construya un applet en Geogebra que: i) dibuje la función $f$ para valores arbitrarios de $c$ y ii) muestre en todo momento, de ser posible, el o los ceros de $f$, cuando existan.
#
#   2.2 Estudie geométrica o numéricamente, si existen, el valor o el rango de valores de la constante $c$ para los cuales la función $f$ tiene: I) un único cero  real, II) dos o mas ceros reales o III) ningún cero real.
#
#   2.3 Para los casos donde exista al menos un cero real de $f$, en un intervalo adecuado, implemente el algoritmo de la bisección en python para hallar los ceros con una precisión no menor a $10^{-6}$. Su implementación debe imprimir en cada iteración $i$, el punto medio $m_i$ y el valor de la función $f(m_i)$ hasta encontrar el cero de $f$ en el intervalo elegido.
#
#   2.4 Justifique la existencia de los ceros en el punto anterior utilizando dos tipos de  argumento: uno geométrico o numérico y otro teórico.
#
#   2.5 Muestre o explique si la función alcanza un valor máximo y un valor mínimo para todo valor de $c$ en un intervalo cerrado arbitrario.
#
#   2.6 Los valores máximos $x^*$ (mínimos) se denominan *locales* cuando $f(x^*)\geq f(x)$ ($f(x^*)\leq f(x)$) para todo $x$ "cercano" a $x^*$. De una definición propia de lo que usted entiende como puntos "cercanos", e ilustre con al menos dos ejemplos, si existen, tales máximos o mínimos locales para la función $f$. En cualquier caso debe argumentar sobre la existencia o no de tales valores.
#
#
# 3. (12 pts) Suponga que  el precio en el  mercado de un determinado producto es $𝑝$ dólares, y que la demanda de ese producto se puede modelar como $$𝐷 (𝑝) =\frac{50000𝑝 + 10000}{𝑝^2} \mbox{unidades}.$$  Al mismo tiempo, suponga que a un precio de $𝑝$ dólares los productores estarán dispuestos a suministrar $𝑆 (𝑝) =\frac{1}{3}𝑝^2 + 2𝑝$ unidades del mismo producto.
#
#   3.1 ¿Cuál es el dominio de las funciones $S$ y $D$?¿son continuas?
#
#   3.2 Explique, en términos de lo discutido en la presente unidad, por qué la ecuación $𝐷 (𝑝) = 𝑆 (𝑝)$, denominada *ecuación de equilibrio* tiene solución. Explore la ecuación geométricamente y argumente sobre el número de soluciones numéricamente posibles.
#
#   3.4 Utilice su algoritmo de bisección para estimar una solución factible de la ecuación de equilibrio $𝐷 (𝑝) = 𝑆 (𝑝)$. ¿Qué significado le daría usted a la solución del problema?¿Es ésta la única solución posible? Argumente cada respuesta
#
# 4. (9 pts) 4.1 Considere la función $$f(x)=\left\{
# \begin{array}{ll}
#       \frac{\sin x}{x}, & x\not=0 \\
#       1, & x=0.
# \end{array} \right.$$ Demuestre o explique por qué la ecuación $f(x)=x$ tiene solución en el intervalo $[0,1]$.
#
#   4.2 Con base en el ejercicio anterior, suponga ahora que $𝑓$ es una función continua en un intervalo $[a, b]$ y que $a ≤ 𝑓(𝑥) ≤ b$ para todo $𝑥\in [a, b]$. Muestre o explique por qué existe un punto $c\in [a, b]$ tal que  $𝑓(𝑐) = 𝑐$.
#
#
# BONUS. Intente encontrar una ecuación de equilibrio, en una variable, para un modelo de interés particular suyo o de su carrera. Halle dicho equilibrio.
#
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
