# %% [markdown]
# # Entrega 7: Teorema fundamental del cálculo
#
# **Departamento de Ciencias Físicas y Exactas / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# A continuación se le pide contestar o resolver por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe trabajar en el cuaderno y traer preguntas para la sesión del martes 16 de noviembre.**
#
# La entrega final está para el día **jueves 18 de noviembre**.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1. (30 ptos) **Teorema Fundamental del Cálculo**
#
#   1.1 Considere la función $\displaystyle f(x)=\frac{1}{x^4+1}$.
#
#   a) Diseñe un applet en GeoGebra que permita muestre simultáneamente la gráfica de la función $f$ y de la función $$F(x)=\int_0^x f(t) \,dt$$ para todo $x\in[-2,2]$. Puede utilizar el código con el que se calcula el valor en la ecuación que define $I_{approx}$ para encontrar los valores de la función $F$. Haga inferencias sobre el comportamiento de $f$ y su relación con $F$.
#
#   b) Si se le pide estimar el área bajo la gráfica de $f$ (sobre el eje X), ¿cree usted que sería posible econtrarla de forma exacta? aproximada? Justifique su respuesta.
#
#     1.2 Considere las curvas $y=x^2$ y $y=(x-2)^2$.
#
#   a) Explique por qué no es posible hallar el area bajo las curvas dadas y sobre el eje X utilizando una sóla integral definida.
#
#   b) Escriba las integrales definidas que le permitan encontrar el área $A$ y aproxime el valor utilizando el código en phyton que estime el valor de $I_{approx}$ para cada caso.
#
#   1.3 Justifique geométrica y numérica o analíticamente por qué $$\int_0^\pi \sin^2x\cos x \, dx=0.$$

# %% [markdown]
# 2. (20 ptos) **Aproximación de integrales**. Considere las siguientes integrales: $$\mbox{(a)} \int_{-2\pi}^{2\pi} \frac{\sin x}{x}\, dx$$
# $$\mbox{(b)} \int_{-2}^5 4x^2+3x-6\, dx$$
# $$\mbox{(c)} \int_{-1}^{1} x\ln (x^2)\, dx$$
#   2.1 Diseñe una función o un código propio en python por cada uno de los siguientes métodos de aproximación numérica para integrales: *regla del punto medio*, *regla del trapecio* y *regla de Simpson*.
#
#   2.2 Para cada integral dada debe usar los tres métodos de aproximación y estimar el valor da cada una con una precisión de $10^{-5}$ utilizando $n=1,5, 10,$ y $ 100$ subintervalos o particiones. Debe producir tablas que le permitan comparar sus resultados según el método y número de subintervalos. Explique si las funciones son o no integrables en el intervalo dado.
#
#   2.3 Mediante un argumento geométrico y otro analítico explique las razones por las que en algunos casos funciona mejor un método que otro.

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
