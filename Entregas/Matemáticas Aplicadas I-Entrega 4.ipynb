# %% [markdown]
# <img src=https://www.icesi.edu.co/wp-content/uploads/2024/10/ICESI_logo_prin_descriptor_RGB_NEGATIVO_0924-768x395.png  width="300" height="200" align="center">
#
# #**<big><big>Matemáticas Aplicadas II</big></big><br><small>Ciencias Físicas & Exactas / FIDCA</small><br><small>_*Entrega 4*_ (Diferenciabilidad y continuidad). </small>**
#
# A continuación se le pide contestar o resolver por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe hacer esta entrega parcial el próximo martes 5 de octubre antes de la clase.**
#
# Para el día jueves 7 de octubre dos grupos estarán encargados de socializar sus resultados de acuerdo a los lineamientos entregados en la sesión del martes anterior.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1.
#
#   1.1 Encuentra la recta tangente a la gráfica de $f (x) = x^2$ en un punto arbitrario $a$. ¿Dónde cruza la recta tangente el eje x? el eje y?
#
#   1.2 Construya un applet en GeoGebra que muestre la recta tangente a la gráfica de la función $f$ en cualquier punto.
#
#   1.3 En la misma gráfica del punto anterior construya la gráfica de la función derivada de $f$. Escriba conjeturas sobre la relación de dicha gráfica con las rectas tangentes a $f$.

# %% [markdown]
# 2. La aproximación lineal de una función $f$ en $a = 2$ es $\ell(x) = 5 (x − 2) + 6$. Encuentre $f (2)$ y $f' (2)$ utilizando la función $\ell$.

# %% [markdown]
# 3. Encuentre una recta que sea tangente a las gráficas de las funciones $f (x) = x^2$ y $g (x) = x^2−2x$ de forma simultánea. ¿Existen mas rectas o puntos de tangencia?

# %% [markdown]
# 4. El volumen de agua en una botella es función de la profundidad del agua. Sea $V (a)$  ​​el volumen hasta la profundidad $a$. Sea $A (a)$ el área de la sección transversal de la botella en la altura $a$.
#
#   4.1 ¿Qué representa $V (a + h) −V (a)$? ($h > 0$).
#
#   4.2 Utilice la figura 3.16 (abajo) para ordenar las siguientes cantidades:
#  $A (a + h) h$, $A (a) h$, $V (a + h) −V (a)$. Escribe tu respuesta usando  desigualdades y argumente sobre la validez de las mismas.
#
#   4.3 Apoyado en las desigualdades del inciso (b), explique por qué el cociente $$\frac{V (a + h) −V (a)}{h}$$ tiende a $A (a)$ cuando $h$ tiende a $0$.

# %% [markdown]
# 5. La temperatura de una varilla en un momento dado varía a lo largo de su longitud. Vea la figura 3.17 (abajo). Sea $T (x)$ la temperatura en el punto $x$.
#
#   5.1 Escriba una expresión para la tasa promedio de cambio en la temperatura entre los puntos $a$ y $a + h$ de la varilla.
#
#   5.2 Suponga que $T' (a)$ es positivo. ¿Hace más calor a la izquierda o a la derecha de $a$?
#
#   5.3 Si la temperatura es constante, ¿quién sería $T'$?

# %%
from google.colab import files
from IPython.display import Image

Image(filename='/content/drive/MyDrive/Figures/rod.jpg')

# %% [markdown]
# 6. La presión atmosférica varía con la altura sobre la superficie de la Tierra. Ver
# Figura 3.18 (abajo). Sea $p (x)$ la presión en "atmósferas" a la altura $x$ en metros.
#
#   6.1 Encuentre la tasa promedio a la que cambia la presión cuando se mueve de una elevación de 2000 m a una elevación de 4000 m.
#
#   6.2 Repita el punto anterior para un movimiento de 4000 m a 6000 m.
#
#   6.3 Utilice sus respuestas a las dos partes previas para hacer una estimación de $p' (4000)$, ¿que tan buena es su estimación? ¿Cómo podría mejorarla?.

# %%
Image(filename='/content/drive/MyDrive/Figures/pressure.jpg')

# %% [markdown]
# 7. Sea $g (x) = x^2 \sin\left(\frac{\pi}{x}\right)$, $g (0) = 0$.
#
#   7.1 Dibuje la gráfica de $g$ en $−1 ≤ x ≤ 1$.
#
#   7.2 Muestre o argumente por qué $g$ es continua en $0$.
#
#   7.3 Demuestre o argumente por qué $g$ es derivable en $0$ y encuentre $g' (0)$.
#
#   7.4 Si considera ahora la función $h (x) = x \sin\left(\frac{\pi}{x}\right)$, $h (0) = 0$, puede concluir que $h$ es continua en 0? diferenciable en 0?

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
