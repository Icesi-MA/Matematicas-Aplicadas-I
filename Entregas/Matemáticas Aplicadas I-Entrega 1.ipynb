# %% [markdown]
# <img src=https://www.icesi.edu.co/wp-content/uploads/2024/10/ICESI_logo_prin_descriptor_RGB_NEGATIVO_0924-768x395.png  width="300" height="200" align="center">
#
# #**<big><big>Matemáticas Aplicadas II</big></big><br><small>Ciencias Físicas & Exactas / FIDCA</small><br><small>_*Entrega 1*_ (Desigualdades, sucesiones y aproximaciones). </small>**
#
# A continuación se le pide contestar o resolver, en **grupos de 4 personas**, las siguientes preguntas utilizando el presente cuaderno para consignar todas sus respuestas.
#
# **Usted debe hacer una entrega parcial (los puntos que haya podido realizar) el próximo martes 31 de Agosto antes de la clase para dar retroalimentación.** La entrega completa será el día jueves 2 de septiembre.
#
#
# **<u>Preguntas</u>**
#
# 1. (5 pts) De acuerdo con la lectura de la sección 1.2 del texto guía de Lax, ¿Qué valor de $m$ escogería usted para que $|\pi - 3.14159265| < 10^{−m}$, y por qué?
#
# 2. (20 pts) En la sección 1.3a del texto guía de Lax se da una forma de aproximar $\sqrt{r}$, para $r\in\mathbb{R_+}$. Vamos a estimar el valor de $\sqrt{5}$
#
#   2.1 Genere una sucesión de aproximaciones $s_1, s_2, . . .,s_n,...$ de $\sqrt{5}$ utilizando la ecuación 1.7 y presente los primeros 10 terminos en una tabla que conste de dos columnas: $\quad n\quad s_n$.
#
#   ¿Que tanto difiere su aproximación del valor de $\sqrt{5}$?
#
#   2.2 Siguiendo las indicaciones al final de la sección ilustre como se puede usar el Teorema del emparedado (Squeeze Theorem 1.7) para mostrar que $$\lim_{n\rightarrow \infty}s_n= \sqrt{5}$$.
#
# 3. (15 pts) Para cada una de las siguientes sucesiones, decida si  converge o diverge. Si la sucesión converge, encuentre su límite. Puede utilizar un argumento numérico, geométrico o algebráico para dar sus respuestas.
#
#   a) $ a_n = \pi^n, \, n= 0,1,2,...$ b) $ b_n = \cos(\pi n), \, n= 0,1,2,...$
#
#   c) $ c_n = \frac{3n^4-n+1}{4n^3+n^2-1}, \, n= 0,1,2,...$ d) $ d_n = \frac{3n^3-n+1}{4n^4+n^2-1}, \, n= 0,1,2,...$
#
#   e) $e_n=\frac{3n^4-n+1}{4n^4+n^2-1}\, n= 0,1,2,...$
#
#   Escriba algunas conjeturas sobre cuando una sucesión converge y cuando diverge según los ejercicios dados.
#
# 4. (10 pts) Explique por qué $$-\frac{1}{n}\leq \frac{\sin(n)}{n} \leq \frac{1}{n}$$
# para $n=1,2,3,...$. ¿Qué puede concluir acerca del $\lim_{n\rightarrow\infty} \frac{\sin(n)}{n}$?
#
# 5. (10 Pts) Sea $𝑎_𝑛 = \left(1 + \frac{1}{n}\right)^n,\;n=1,2,3,...$,
#
#   a. Calcule $𝑎_1, 𝑎_2, 𝑎_3, 𝑎_4$ y $𝑎_5$.
#
#   b. Calcule los valores de $𝑎_𝑛$ para $𝑛 = 1, 2, 3,. . . , 200$.
#
#   c. Grafique los puntos $(𝑛, 𝑎_𝑛)$ para $𝑛 = 1, 2, 3,. . . , 200$, junto con la línea horizontal $𝑦 = 𝑒$.
#
#   d. ¿Parece razonable que $\lim_{n\rightarrow \infty} 𝑎_𝑛 = e$?
#
#   e. ¿Cuál es el valor más pequeño de $𝑛$ para el cual $𝑎_𝑛 > 2.7$?
#
#   f. ¿Cuál es el primer valor de $𝑛$ para el que $|𝑎_𝑛 - e| < 0.001$ ? Recuerda que $e = 2.71828$ a cinco decimales.
#
# 6. (10 pts) Sea $𝑎_𝑛 = 1.01𝑛$ y $𝑏_𝑛 = 0.99𝑛$ para $𝑛 = 0, 1, 2,...$. En el mismo gráfico, trace los puntos $(𝑛, 𝑎_𝑛)$ y $(𝑛, 𝑏_𝑛)$ para $𝑛 = 0, 1, 2,. . . , 200$. ¿Cómo se comparan estas dos gráficas?
# ¿Las secuencias convergen?
#
# 7. (10 pts) Sea $𝑎_𝑛 = \frac{10^𝑛}{ 𝑛!}$ para $𝑛 = 1, 2, 3,. . .$.
#
#   a. Grafique los puntos $(𝑛, 𝑎_𝑛)$ para $𝑛 = 1, 2, 3,. . . , 100$.
#
#   b. De la imagen del inciso (a), ¿puedes adivinar $\lim_{𝑛\rightarrow\infty} = 𝑎_𝑛$?
#
#   c. ¿Cuál es el valor máximo de $𝑎_𝑛$ para $𝑛 = 1, 2, 3,. . . , 100$?
#
#   d. ¿Puede ver por qué $\lim_{𝑛\rightarrow\infty} \frac{k^𝑛}{ 𝑛!}= 0 $ para cualquier constante $𝑘$? Explique.
#
# 8. (10 pts) Considere la sucesión $\{𝑎_𝑛\}$ con $𝑎_1 = 1$ y $$𝑎_{𝑛 + 1}=c 𝑎_𝑛$$ para $𝑛 = 1, 2, 3,. . .$ donde $c\in\mathbb{Z}$. Trace los puntos $(𝑛, 𝑎_𝑛)$ para $𝑛 = 1, 2, 3,. . . , 50$ y para al menos cuatro valores distintos de $c$, por ejemplo, un valor negativo, un valor positivo, un valor menor que 1, etc. Observe el comportamiento de la sucesión para cada $c$ y formule conjeturas con respecto a cuando una sucesión definida de esta forma tiene un límite, y como lo podría calcular.
#
# 9. (10 pts) Considere la sucesión $$ a_n = \frac{1}{n^2}$$ Para un $\epsilon> 0$ arbitrario, encuentre el entero más pequeño $N$ para el cual $$| 𝑎_𝑛 - 𝐿 | < \epsilon$$ siempre que $𝑛> 𝑁$. Verifique que su valor de $𝑁$ funcione para el caso particular $\epsilon = 0.001$.
#
#
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
