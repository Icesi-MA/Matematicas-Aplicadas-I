# %% [markdown]
# # Entrega 5: Teoría de diferenciabilidad
#
# **Departamento de Ciencias Físicas y Exactas / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# A continuación se le pide contestar o resolver por grupo las siguientes preguntas, utilizando una copia del presente cuaderno para consignar todas sus respuestas con el formato requerido.
#
# **Usted debe hacer esta entrega parcial el próximo martes 19 de octubre antes de la clase.**
#
# Para el día jueves 21 de octubre dos grupos estarán encargados de socializar sus resultados de acuerdo a los lineamientos entregados en la sesión del martes anterior.
#
# **<u>Preguntas</u>**
#
# A continuación encuentra separadas por celda cada pregunta, así usted solo debe continuar escribiendo en la celda para dar cada respuesta. No olvide que todas sus respuestas deben ir acompañadas de al menos un argumento geométrico o numérico y uno algebráico o en lenguaje natural.

# %% [markdown]
# 1. (10 ptos) *Razones de cambio y regla de la cadena.*
#
#   1.1 La energía cinética de un objeto que se mueve en línea recta está dada por $K = \frac{1}{2}mv^2 $, donde $𝑚$ es la masa del objeto y $𝑣$ es su velocidad. Si la aceleración del
# objeto, $𝑎 = \frac{dv}{dt}$, es  9.8 metros por segundo, encuentre la razón de cambio de la energía cinética cuando $𝑣 = 10$ metros por segundo.
#
#   1.2 Suponga que un derrame de petróleo de forma circular tiene 0.009 metros de espesor y un radio que aumenta a un ritmo de 0.6 metros por hora. Cuando el radio es de 30 metros, ¿a qué tasa aumenta el volumen del derrame de petróleo?

# %% [markdown]
# 2. (10 ptos) *Derivada implícita*. Considere la curva formada por el conjunto de puntos $ (x,y)$ que satisfacen la ecuación $$x^3+y^3−9xy = 0.$$
#
#   2.1 Diseñe un applet en GeoGebra que dibuje para un punto arbitrario sobre la curva su respectiva recta tangente.
#
#   2.2 Encuentre, si existen, aquellos puntos $ (x,y)$ donde no existe la derivada, $y'= \frac{dy}{dx}$.  En su respuesta debe dar dos argumentos, uno al menos  de tipo numérico o geométrico.

# %% [markdown]
# 3. (6 ptos) *Teoría de diferenciabilidad*
#
#   3.1 Explique utilizando teoremas de diferenciabilidad y continuidad por qué la ecuación $ x^4-2=2𝑥^2$ tiene exactamente una solución en el intervalo $[1, 2]$ y exactamente una solución en el intervalo $[−2, −1]$.
#
#   3.2 Considere la función $v(x)=|x|$ en el intervalo $[-1,1]$. Verifique que aunque el cociente $\frac{v(1)-v(-1)}{1-(-1)} = 0$, no existe un punto $𝑐$ en $(−1, 1)$ tal que $𝑓'(𝑐) = 0$. ¿Esto contradice el teorema del valor medio?

# %% [markdown]
# 4. (9 ptos) Máximos y mínimos
#
#   4.1 Encuentre los  máximos y los mínimos de la función
# $f (x) = 2x^3−3x^2−12x+8$ en cada uno de los siguientes intervalos
# (a) $[−2.5,4]$, (b) $[−2,3]$ y  (c) $[−2.25,3.75]$
#
#   4.2 Suponga que se lleva a cabo un experimento como el de la figura y se asume que los datos tienen un comportamiento lineal, es decir, supondremos que los datos obedecen un modelo de la forma $y=mx+b$.
# <p><a href="https://commons.wikimedia.org/wiki/File:Linear_regression.svg#/media/File:Linear_regression.svg"><img src="../_static/linear-regression.svg" alt="Linear regression.svg"></a><br><a href="https://commons.wikimedia.org/w/index.php?curid=11967659">Link</a></p>
#
#   Sean $\{(x_1, y_1), (x_2, y_2),. . . , (x_n, y_n)$ los datos obtenidos en el experimento y suponga que en el modelo $b=0$. Encuentre el valor de $m$, en términos de $x_i$ y $y_i$, que minimiza $E$, la suma de los cuadrados de los errores entre las medidas observadas y la función lineal
# $y = mx$: $$E = (y_1−mx_1)^2 +(y_2−mx_2)^2+· · ·+(y_n−mx_n)^2.$$
#
#   4.3 Encuentre, si existen, el valor mínimo y el valor máximo de $$𝑓 (𝑡) =\frac{\sin t}{t^2}$$  en $(0, 2\pi)$.

# %% [markdown]
# 5. (15 ptos) Suponga que $𝑓$ es diferenciable en un intervalo abierto que contiene el intervalo cerrado $[𝑎, 𝑏]$.
#
#   5.1 Muestre o explique por qué para cualquier $𝑥$ en $(𝑎, 𝑏)$, $$𝑓 (𝑥) = 𝑓 (𝑎) + 𝑓 ^{\prime} (𝑐) (𝑥 - 𝑎)$$
# para algún punto $𝑐$ con $𝑎 <𝑐 <𝑥$.
#
#   5.2 Asumiendo que $𝑓^{\prime}$ es continua en $[𝑎, 𝑏]$ y diferenciable en $(𝑎, 𝑏)$, utilice el teorema del valor medio para mostrar que  existe un punto $𝑑$ con $𝑎 < 𝑑 < 𝑐$ tal que
# $$𝑓(𝑥) = 𝑓(𝑎) + 𝑓^{\prime}(𝑎)(𝑥 − 𝑎) + 𝑓^{\prime\prime}(𝑑)(𝑐 − 𝑎)(𝑥 − 𝑎).$$
#
#   5.3 Recordemos que la función  $𝑇(𝑥) = 𝑓^{\prime}(𝑐)(𝑥 − 𝑐) + 𝑓(𝑐),$ es la mejor transformación afín de una función $f$ en el punto $c$. Es fácil ver que si elegimos $ ℎ = 𝑥 − 𝑎$, entonces
# $𝑓(𝑎 + ℎ) − 𝑇(𝑎 + ℎ) = 𝑓^{\prime\prime}(𝑑)(𝑐 − 𝑎)ℎ.$ Suponiendo que $𝑓''$ es continua en $[𝑎, 𝑏]$, argumente o demuestre por qué
# $$\left|\frac{𝑓 (𝑎 + ℎ) - 𝑇 (𝑎 + ℎ)}{ℎ^2}\right|\leq M$$
# para alguna constante $𝑀$. Esta afirmación significa que la función resto
# $$𝑅 (ℎ) = 𝑓 (𝑎 + ℎ) - 𝑇 (𝑎 + ℎ)$$
# es $𝑂 (ℎ^2)$, es decir, $𝑅 (ℎ)$ tiende a 0 al menos tan rápido como $ℎ^2$.
#
#   5.4 Considere las funciones $f(x)=\ln (1+x)$ y $f(x)=e^{-x^2/2}$ en el intervalo $(-1,1)$. Haga una visualización en python o GeoGebra que permita ver en un mismo gráfico las dos funciones $f$ dadas y las dos aproximaciones según las formulas dadas en 5.1 y 5.2. ¿Cuál aproximación es mejor?¿Por qué? ¿Cómo cree usted podría mejorar la aproximación?

# %% [markdown]
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
