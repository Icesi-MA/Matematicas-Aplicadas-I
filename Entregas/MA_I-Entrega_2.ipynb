# %% [markdown]
# # Entrega 2: Límites y continuidad
#
# **Departamento de Ciencias Físicas y Exactas / FIDCA**
#
# <!--
# Copyright © Angela Villota y Aníbal Sosa.
#
# El contenido textual está licenciado bajo Creative Commons
# Attribution-NonCommercial 4.0 International (CC BY-NC 4.0).
#
# El código y la lógica de los notebooks están licenciados bajo
# PolyForm Noncommercial License 1.0.0.
#
# Consulte el archivo LICENSE del repositorio para conocer los términos completos.
# -->
#
# A continuación se le pide contestar o resolver, en **grupos de 4 personas**, las siguientes preguntas utilizando el presente cuaderno para consignar todas sus respuestas.
#
# **Usted debe hacer una entrega parcial el próximo martes 14 de Septiembre antes de la clase para dar retroalimentación.** La entrega completa será el fin de semana siguiente.
#
#
# **<u>Preguntas</u>**
#
# 1. Considere el ejemplo 2.12 de la sección 2.2 del texto guía de Lax. Explique en sus palabras, puede apoyarse con una gráfica, la última afirmación: "Este es el tipo de comportamiento que la continuidad prohibe".
#
# 2. Considere los siguientes límites:
#
# $$a) \lim_{𝑥 → 0} 4𝑥^3 − 6𝑥^2 + 𝑥 − 7,\quad b) \lim_{𝑥 → 3}\frac{3𝑥 + 4}{2𝑥^2 + 2𝑥 − 1}$$
# $$c) \lim_{𝑥 → 2} \frac{𝑥^2  − 4}{x-2},\quad d) \lim_{𝑥 → 2} \frac{𝑥^2  + 4}{x-2}$$
# $$  e) \lim_{t → 1} g(t),\quad g(t) = \left\{
# \begin{array}{ll}
#       t^2+1, & t\leq1 \\
#       3t+4, & t >1.
# \end{array}
# \right.\quad f) \lim_{t → 2} h(t),\quad h(t) = \left\{
# \begin{array}{ll}
#       2t+3, & t\leq2 \\
#       2t^2-1, & t >2
# \end{array}
# \right.$$
#
#   2.1 De acuerdo con la discusión hecha en clase, la definicion 2.3.1 y los ejemplos subsecuentes del texto de Sloughter, en cada uno de los siguientes casos utilice dos sucesiones distintas $x_n$ y $y_n$, para evaluar los límites dados en la forma $$ \lim_{x → c} f(x). $$ Es decir, escoja de manera adecuada las sucesiones para que pueda estudiar los límites $$ \lim_{n → \infty} f(x_n),\quad\lim_{n → \infty} f(y_n)$$ donde $$ \lim_{n → \infty} x_n = c$$ con $x_n<c$ y $$ \lim_{n → \infty} y_n = c$$ con $y_n>c$. *Nota.* Recuerde que el valor de $c$ varía según el  límite considerado.
#
#   2.2 Argumente por qué  existe o no $$ \lim_{x → c} f(x) $$ de acuerdo con los resultados obtenidos en los límites anteriores.
#
# 3. Considere una función de la forma :
#   $$
#   h(t) = \left\{
#   \begin{array}{ll}
#       t^2-1, & t\leq c \\
#       g(t)+a, & t > c
#   \end{array}
#   \right.$$
#
#   3.1 Usted debe dar tres ejemplos distintos de funciones  $h$ discontinuas en $c$, modificando adecuadamente los valores de las constantes $a$ y $c$, así como identificando una función $g$. Una función debe tener una discontinuidad tipo salto, otra una discontinuidad tipo hueco y otra una de tipo infinito (o comportamiento asintótico al infinito). Debe explicar o sustentar cada una de sus elecciones.
#
#   3.2 Escoja valores de $a$, $c$ y una función $g$ adecuada para que $h$ sea una función continua en toda la recta real. Argumente su respuesta.
#
# 4. Explique o demuestre por qué  la función $𝑔(𝑥) = 𝑥^2 \sin(𝑥^2 + 1)$ es continua en el intervalo (−∞, ∞).
#
# 5. Recordemos la ***función de Heaviside:***
# $$ H(t) = \left\{
# \begin{array}{ll}
#       0, & t<0 \\
#       1, & t \geq 0
# \end{array}
# \right. ,$$ y considere el  intervalo $I=[−5, 5]$.
#
# 5.1 Estudie la continuidad de $𝑓(𝑡) = 𝐻(𝑡^2 + 1)$ en el intervalo $I$. Haga la gráfica de $𝑓$ en $I$.
#
# 5.2 Discuta la continuidad de $𝑓(𝑡) = 𝐻(𝑡^2 - 1)$ en el intervalo $I$. Haga la gráfica de $𝑓$ en $I$.
#
# 6. Considere la función $$ f(x)=\frac{\sin x}{x}.$$ Determine si $f$ tiene una discontinuidad removible o no. Si tiene una discontinuidad removible en $x=c$, defina una función  $h$ que sea igual a $f$, excepto en $x=c$, pero continua en toda la recta real, es decir, incluso en $x=c$. Explique detalladamente su respuesta.
#
# **La entrega solo se acepta en el formato de un cuaderno python colab .**
